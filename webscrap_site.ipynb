# %% [markdown]
# ## Webscraping random site

# %%
import requests
url = "https://www.espncricinfo.com/records/trophy/batting-most-runs-career/indian-premier-league-117"
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import requests
#       2 url = "https://www.espncricinfo.com/records/trophy/batting-most-runs-career/indian-premier-league-117"
#
# ModuleNotFoundError: No module named 'requests'

# %%
response = requests.get(url)
response
# Out:
# <Response [200]>

# %% [markdown]
# ##### successful connection

# %%
from bs4 import BeautifulSoup

# %%
soup = BeautifulSoup(response.text,'html.parser')
soup.title
# Out:
# <title>Indian Premier League Trophy batting most runs career | ESPNcricinfo</title>

# %%
soup.body
# Out:
# <body><div id="__next"><script>
#     (function() {
#       let theme = window?.localStorage?.getItem('ci-theme-preference') || 'LIGHT';
#
#       // check ci-app-theme cookie required for native app theme support
#       const appTheme = Cookies.get('ci_app_theme') || Cookies.get('ci-app-theme');
#
#       if(appTheme) {
#         theme = appTheme;
#         window.hsciapp = { theme: appTheme };
#       }
#
#       if (theme === 'DARK') {
#         document.body.dataset.colorTheme = 'dark';
#       }
#
#     })()
# ...

# %% [markdown]
# #### Getting the records from the url

# %%
import pandas as pd
table =  pd.read_html(url)
table
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import pandas as pd
#       2 table =  pd.read_html(url)
#       3 table
#
# ModuleNotFoundError: No module named 'pandas'

# %% [markdown]
# #### Converting to dataframe

# %%
df = table[0].iloc[0:150]
df
# Out:
#                         Player       Span  Mat  Inns  NO  Runs    HS    Ave  \
# 0                V Kohli (RCB)  2008-2023  237   229  34  7263   113  37.24
# 1    S Dhawan (DC/MI/PBKS/SRH)  2008-2023  217   216  29  6617  106*  35.38
# 2           DA Warner (DC/SRH)  2009-2023  176   176  22  6397   126  41.53
# 3            RG Sharma (DC/MI)  2008-2023  243   238  28  6211  109*  29.57
# 4            SK Raina (CSK/GL)  2008-2021  205   200  30  5528  100*  32.51
# ..                         ...        ...  ...   ...  ..   ...   ...    ...
# 145        J Botha (DC/KKR/RR)  2009-2015   34    28   8   409   67*  20.45
# 146         LR Shukla (DC/KKR)  2008-2014   47    34   7   405   48*  15.00
# 147           RM Patidar (RCB)  2021-2022   12    11   1   404  112*  40.40
# 148         MK Lomror (RCB/RR)  2018-2023   30    25   4   402   54*  19.14
# 149            AL Menaria (RR)  2011-2013   29    23   2   401    40  19.09
#
#        BF      SR 100  50   0   4s   6s
# ...

# %%
df.head()
# Out:
#                       Player       Span  Mat  Inns  NO  Runs    HS    Ave  \
# 0              V Kohli (RCB)  2008-2023  237   229  34  7263   113  37.24
# 1  S Dhawan (DC/MI/PBKS/SRH)  2008-2023  217   216  29  6617  106*  35.38
# 2         DA Warner (DC/SRH)  2009-2023  176   176  22  6397   126  41.53
# 3          RG Sharma (DC/MI)  2008-2023  243   238  28  6211  109*  29.57
# 4          SK Raina (CSK/GL)  2008-2021  205   200  30  5528  100*  32.51
#
#      BF      SR 100  50   0   4s   6s
# 0  5586  130.02   7  50  10  643  234
# 1  5203  127.17   2  50  11  750  148
# 2  4572  139.91   4  61  11  646  226
# 3  4776  130.04   1  42  16  554  257
# 4  4043  136.73   1  39   8  506  203

# %% [markdown]
# #### Saving dataframe as CSV

# %%
df.to_csv('ESPN_IPL.csv')
